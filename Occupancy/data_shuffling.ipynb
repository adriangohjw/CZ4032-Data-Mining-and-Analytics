# %% [markdown]
# ## To be ran ONCE only (if csv files not created for this dataset) to produce cleaned and shuffled data

# %%
import pandas as pd
import numpy as np

# %%
#Read in txt file of training and testing record
train_df_occ = pd.read_csv("datatraining.txt")
test_df_occ = pd.read_csv("datatest.txt")

#Dropping date attribute 
train_df_occ = train_df_occ.drop(columns='date')
test_df_occ = test_df_occ.drop(columns='date')

#View briefly train dataset
train_df_occ.head()
# Out:
#    Temperature  Humidity  Light     CO2  HumidityRatio  Occupancy
# 1        23.18   27.2720  426.0  721.25       0.004793          1
# 2        23.15   27.2675  429.5  714.00       0.004783          1
# 3        23.15   27.2450  426.0  713.50       0.004779          1
# 4        23.15   27.2000  426.0  708.25       0.004772          1
# 5        23.10   27.2000  426.0  704.50       0.004757          1

# %%
#Shuffling of data
train_df_occ = train_df_occ.sample(frac=1)
test_df_occ = test_df_occ.sample(frac=1)

# %%
train_df_occ
# Out:
#       Temperature  Humidity  Light    CO2  HumidityRatio  Occupancy
# 4926    19.390000    31.200    0.0  434.5       0.004343          0
# 3238    20.100000    18.790    0.0  439.0       0.002726          0
# 5024    19.245000    31.550    0.0  439.0       0.004352          0
# 7631    20.290000    32.900    0.0  482.0       0.004846          0
# 3539    19.700000    19.390    0.0  439.0       0.002744          0
# ...           ...       ...    ...    ...            ...        ...
# 3617    19.700000    19.390    0.0  444.0       0.002744          0
# 123     21.890000    27.100    0.0  548.0       0.004401          0
# 6568    19.445000    25.945    0.0  473.5       0.003620          0
# 4845    19.426667    30.860    0.0  441.0       0.004305          0
# 6020    19.500000    27.700    0.0  453.0       0.003879          0
#
# [8143 rows x 6 columns]

# %%
test_df_occ
# Out:
#       Temperature   Humidity       Light          CO2  HumidityRatio  \
# 2019       21.000  26.150000    0.000000   608.750000       0.004019
# 1053       20.290  22.600000    0.000000   435.200000       0.003321
# 1173       20.315  22.767500    0.000000   434.500000       0.003351
# 905        20.500  22.390000    0.000000   435.000000       0.003333
# 1236       20.790  24.790000  433.000000   672.666667       0.003759
# ...           ...        ...         ...          ...            ...
# 2677       21.000  25.390000  444.000000   718.000000       0.003901
# 2160       20.890  24.890000    0.000000   550.000000       0.003798
# 290        22.600  25.525000  433.500000   882.500000       0.004328
# 1470       22.500  26.963333  641.333333  1033.250000       0.004546
# 1622       23.125  29.472500  469.000000  1212.250000       0.005166
#
#       Occupancy
# 2019          0
# 1053          0
# 1173          0
# 905           0
# 1236          1
# ...         ...
# ...

# %%
# Export the vector training and test data with label class to csv, the shuffled version every time run will be different, as backup
train_df_occ.to_csv('train_df_occ.csv', index=False)
test_df_occ.to_csv('test_df_occ.csv', index=False)

# %%
test_df = test_df_occ.drop(columns='Occupancy')
test_df
# Out:
#       Temperature   Humidity       Light          CO2  HumidityRatio
# 2019       21.000  26.150000    0.000000   608.750000       0.004019
# 1053       20.290  22.600000    0.000000   435.200000       0.003321
# 1173       20.315  22.767500    0.000000   434.500000       0.003351
# 905        20.500  22.390000    0.000000   435.000000       0.003333
# 1236       20.790  24.790000  433.000000   672.666667       0.003759
# ...           ...        ...         ...          ...            ...
# 2677       21.000  25.390000  444.000000   718.000000       0.003901
# 2160       20.890  24.890000    0.000000   550.000000       0.003798
# 290        22.600  25.525000  433.500000   882.500000       0.004328
# 1470       22.500  26.963333  641.333333  1033.250000       0.004546
# 1622       23.125  29.472500  469.000000  1212.250000       0.005166
#
# [2665 rows x 5 columns]

# %%
test_df.to_csv('test_df.csv', index=False)
